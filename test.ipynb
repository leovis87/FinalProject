# %%
from typing import Dict, List, Tuple, Optional, Union
import anthropic
import os
import logging
import torch

# %%
# ===== LLM model selector =====
Use_Claude = True

# ============================================================================
# Clude API_key 호출
# anthropic.Anthropic() => API 클라이언트 생성
# ============================================================================
client = anthropic.Anthropic(
    api_key = os.environ.get("ANTHROPIC_API_KEY")
)

# %%
# ============================================================================
# Claude models - claude API
# models["sonnet"] 으로 모델명 로드
# ============================================================================
models = {
    "sonnet": "claude-sonnet-4-20250514",
    "haiku": "claude-3-5-haiku-20241022",
    "opus": "claude-opus-4-20250514"
}

# 저렴이: models['haiku']
# 기본: models['sonnet']

# %%
def set_prompt(role: str,
                content: str) -> Dict:
    """
    API에게 prompt를 주입하기 위한 메시지 구조 생성
        role: "user", "assistant", "system" 중 하나
        content: 메시지 텍스트
    """
    return {
        "role": role,
        "content": content
    }

# %%
conversation = []

def chat_haiku(query: str):
    # 1. 사용자 입력 추가

    conversation.append(set_prompt("user", query))

    # 2. 모델 호출

    response = client.messages.create(
        model = models['haiku'],        # 사용할 모델 (위에서 보고 선택)
        max_tokens = 1024,
        messages = conversation         # 지금까지의 대화 히스토리 전달
    )

    # 3. 모델 응답 추출
    answer = response.content[0].text

    # 4. conversation에 기록
    conversation.append(set_prompt("assistant", answer))

    return answer

# %%
conversation = []

def chat_sonnet(query: str):
    # 1. 사용자 입력 추가

    conversation.append(set_prompt("user", query))

    # 2. 모델 호출

    response = client.messages.create(
        model = models['sonnet'],        # 사용할 모델 (위에서 보고 선택)
        max_tokens = 1024,
        messages = conversation         # 지금까지의 대화 히스토리 전달
    )

    # 3. 모델 응답 추출
    answer = response.content[0].text

    # 4. conversation에 기록
    conversation.append(set_prompt("assistant", answer))

    return answer

# %%
from datetime import datetime, timezone, timedelta
import zoneinfo
KST2 = datetime.now(timezone(timedelta(hours = 9)))
KST2_strf = datetime.now(timezone(timedelta(hours = 9))).strftime("%H:%M:%S")
KST = datetime.now(zoneinfo.ZoneInfo("Asia/Seoul"))
KST_strf = datetime.now(zoneinfo.ZoneInfo("Asia/Seoul")).strftime("%H:%M:%S")
KST, KST_strf, KST2, KST2_strf
# Out:
# (datetime.datetime(2025, 12, 26, 14, 8, 1, 977331, tzinfo=zoneinfo.ZoneInfo(key='Asia/Seoul')),
#  '14:08:01',
#  datetime.datetime(2025, 12, 26, 14, 8, 1, 977331, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))),
#  '14:08:01')

# %%
KST4 = datetime.now(zoneinfo.ZoneInfo("Asia/Seoul"))

# %%
type(KST4)
# Out:
# datetime.datetime

# %%
from websocket_test.backend.utils.set_time import set_time

# %%
type(set_time(False))
# Out:
# str

# %%
import zoneinfo

print(zoneinfo.available_timezones())
# Out:
# {'Asia/Ujung_Pandang', 'Asia/Kashgar', 'Antarctica/McMurdo', 'WET', 'Asia/Dili', 'America/Winnipeg', 'Asia/Katmandu', 'Pacific/Easter', 'Asia/Bahrain', 'Chile/EasterIsland', 'America/Moncton', 'America/Fort_Wayne', 'America/Thunder_Bay', 'Antarctica/DumontDUrville', 'Pacific/Palau', 'Chile/Continental', 'Asia/Qyzylorda', 'Pacific/Marquesas', 'EST', 'Pacific/Tarawa', 'Greenwich', 'Zulu', 'Eire', 'America/Cayenne', 'Australia/Yancowinna', 'America/Argentina/Salta', 'Europe/Riga', 'Europe/Kiev', 'Africa/Libreville', 'America/Guayaquil', 'America/Managua', 'Etc/GMT+4', 'Asia/Seoul', 'Australia/South', 'Europe/Oslo', 'America/Menominee', 'Egypt', 'Africa/Juba', 'Australia/Queensland', 'America/Nipigon', 'America/Dominica', 'Etc/GMT-1', 'Etc/UCT', 'Africa/Mogadishu', 'America/Whitehorse', 'Europe/Monaco', 'Africa/Djibouti', 'America/Rosario', 'Europe/Paris', 'America/Argentina/La_Rioja', 'America/Juneau', 'America/Indiana/Tell_City', 'America/Tegucigalpa', 'America/Manaus', 'America/Detroit', 'America/Montevideo', 'Asia/Aqtobe', 'Europe/Budapest', 'Indian/Mauritius', 'Africa/Algiers', 'Etc/GMT-8', 'America/Martinique', 'Africa/Bangui', 'Indian/Maldives', 'Africa/Maputo', 'Etc/GMT+0', 'Asia/Macau', 'America/Indiana/Indianapolis', 'Asia/Omsk', 'Australia/Lindeman', 'Australia/Broken_Hill', 'Pacific/Efate', 'Pacific/Kanton', 'Europe/Gibraltar', 'Canada/Mountain', 'America/Halifax', 'Africa/Bujumbura', 'Asia/Kathmandu', 'Asia/Magadan', 'Asia/Taipei', 'Etc/GMT-3', 'Africa/Kigali', 'Europe/Guernsey', 'US/Indiana-Starke', 'America/Creston', 'America/Indiana/Marengo', 'Pacific/Fakaofo', 'Europe/Lisbon', 'Australia/Sydney', 'Pacific/Enderbury', 'Canada/Saskatchewan', 'Europe/Minsk', 'Mexico/General', 'US/Pacific', 'Asia/Kuala_Lumpur', 'Africa/Ouagadougou', 'Pacific/Rarotonga', 'Europe/Madrid', 'America/Ojinaga', 'Etc/UTC', 'Etc/GMT', 'Africa/Dar_es_Salaam', 'America/North_Dakota/Center', 'Asia/Sakhalin', 'US/Aleutian', 'Asia/Qostanay', 'Europe/Skopje', 'America/Regina', 'America/Thule', 'Pacific/Wake', 'NZ-CHAT', 'Etc/GMT-2', 'America/Costa_Rica', 'America/Argentina/ComodRivadavia', 'America/Santarem', 'Europe/Ulyanovsk', 'America/Louisville', 'Pacific/Saipan', 'US/East-Indiana', 'Indian/Kerguelen', 'Asia/Chungking', 'Atlantic/Cape_Verde', 'Europe/Belfast', 'GB', 'America/Barbados', 'Africa/Lome', 'America/Grand_Turk', 'Asia/Ashkhabad', 'America/Tortola', 'Pacific/Apia', 'Europe/Podgorica', 'Asia/Yekaterinburg', 'Pacific/Niue', 'Asia/Dacca', 'Australia/Melbourne', 'Asia/Tel_Aviv', 'Australia/LHI', 'America/Montserrat', 'Canada/Central', 'Etc/GMT-10', 'America/Mendoza', 'Europe/Nicosia', 'America/Lower_Princes', 'Europe/Dublin', 'Etc/GMT+2', 'Africa/Windhoek', 'Europe/Zaporozhye', 'Europe/Athens', 'America/Marigot', 'Africa/Ndjamena', 'America/Dawson', 'Europe/Copenhagen', 'Asia/Ulan_Bator', 'Asia/Baghdad', 'Indian/Mayotte', 'America/Chihuahua', 'America/Anguilla', 'America/St_Thomas', 'Europe/Amsterdam', 'America/Belize', 'HST', 'Atlantic/St_Helena', 'Pacific/Guam', 'NZ', 'Etc/GMT-7', 'Europe/Vaduz', 'Australia/Brisbane', 'America/Monterrey', 'Asia/Thimbu', 'America/Virgin', 'Asia/Qatar', 'Asia/Kolkata', 'Asia/Ho_Chi_Minh', 'Africa/Kinshasa', 'Etc/GMT-9', 'Africa/Gaborone', 'Asia/Damascus', 'Pacific/Samoa', 'America/Argentina/San_Juan', 'America/Yellowknife', 'Asia/Vladivostok', 'Cuba', 'Atlantic/Madeira', 'America/Nome', 'America/Port_of_Spain', 'America/Mexico_City', 'Antarctica/Troll', 'Europe/Malta', 'Europe/Bucharest', 'Pacific/Norfolk', 'US/Michigan', 'America/Adak', 'Africa/Nairobi', 'Etc/GMT+1', 'America/Anchorage', 'UTC', 'America/Indiana/Winamac', 'Europe/Tallinn', 'America/Pangnirtung', 'Australia/Canberra', 'America/Merida', 'America/Mazatlan', 'America/Caracas', 'Asia/Bangkok', 'Asia/Jerusalem', 'Atlantic/Canary', 'Antarctica/Mawson', 'Europe/Kyiv', 'Mexico/BajaNorte', 'Asia/Kuwait', 'Asia/Pyongyang', 'Etc/GMT-11', 'America/Cordoba', 'Portugal', 'America/Argentina/Jujuy', 'Pacific/Auckland', 'Etc/Zulu', 'Asia/Samarkand', 'Etc/GM ...
